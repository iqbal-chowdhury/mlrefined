# %%
from sklearn.kernel_ridge import KernelRidge

# %%
# import gridworld library - make sure this is executed prior to running any gridworld cell
import sys
import matplotlib.pyplot as plt
sys.path.append('demo_python_backend_files')
# %matplotlib inline

from regression_viz_lib import Data_Fit_Demo1 as demo
fig = plt.figure(figsize = (5,4))
ax = fig.add_subplot(111)
        
test = demo.Fit_Bases()
test.load_data('demo_datasets/noisy_sin_sample.csv')
test.load_target('demo_datasets/sin_function.csv')
test.plot_all(ax)

# %%
# import Draw_Bases class for visualizing various basis element types
from regression_viz_lib import Draw_Bases as demo
bases = demo.Draw_Bases()

# plot the first 4 elements of the polynomial basis
bases.show_1d_poly()

# %%
# import class for visualizing complete function approximation
from regression_viz_lib import Function_Fit_Demo1 as demo
func_fit = demo.Fit_Bases()
func_fit.load_target('demo_datasets/sin_function.csv')
func_fit.browse_poly_fit()

# %%
# import gridworld library - make sure this is executed prior to running any gridworld cell
import sys
import numpy as np
sys.path.append('demo_python_backend_files')
# %matplotlib inline

# import class for visualizing complete supervised learning (i.e., noisy sampled function approximation)
from regression_viz_lib import Data_Fit_Demo1 as demo
data_fit = demo.Fit_Bases()
data_fit.load_data('demo_datasets/3d_noisy_sin_sample.csv')
data_fit.load_target('demo_datasets/3d_sin_function.csv')

data_fit.browse_fit(model = 'poly',param_range = np.arange(1,5))
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgJIQLQWEQTGOKIXUB">
#     <br>
#     <input id="_anim_sliderJIQLQWEQTGOKIXUB" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animJIQLQWEQTGOKIXUB.set_frame(parseInt(this.value));"></input>
#     <br>
#
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgJIQLQWEQTGOKIXUB";
#     var slider_id = "_anim_sliderJIQLQWEQTGOKIXUB";
#     var loop_select_id = "_anim_loop_selectJIQLQWEQTGOKIXUB";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#
#
#     /* set a timeout to make sure all the above elements are created before
#        the object is initialized. */
#     setTimeout(function() {
#         animJIQLQWEQTGOKIXUB = new Animation(frames, img_id, slider_id, 250, loop_select_id);
#     }, 0);
#   })()
# </script>

# %%
# import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d import Axes3D
# fig = plt.figure(figsize = (5,5))
# ax = plt.subplot(111,projection = '3d')
# data_fit.show_setup(ax)
# ax.plot_surface(data_fit.target_x[0,:].T,data_fit.target_x[1,:].T,data_fit.target_y,alpha = 0.1,color = 'r',zorder = 0,shade = True,linewidth = 0)
import math
# Out:
# array([[ 0.        ,  0.00200401,  0.00400802, ...,  0.99599198,
#          0.99799599,  1.        ],
#        [ 0.        ,  0.00200401,  0.00400802, ...,  0.99599198,
#          0.99799599,  1.        ],
#        [ 0.        ,  0.00200401,  0.00400802, ...,  0.99599198,
#          0.99799599,  1.        ],
#        ...,
#        [ 0.        ,  0.00200401,  0.00400802, ...,  0.99599198,
#          0.99799599,  1.        ],
#        [ 0.        ,  0.00200401,  0.00400802, ...,  0.99599198,
#          0.99799599,  1.        ],
#        [ 0.        ,  0.00200401,  0.00400802, ...,  0.99599198,
#          0.99799599,  1.        ]])

# %%
# import class for visualizing complete supervised learning (i.e., noisy sampled function approximation)
from Data_Fit_Demo_3d import two_dim_regression_fits
# %matplotlib inline
data_fit = two_dim_regression_fits()
data_fit.load_data('demo_datasets/3d_noisy_sin_sample.csv')
data_fit.load_target('demo_datasets/3d_sin_function.csv')
data_fit.plot_basics()
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-1-7928008901ce> in <module>()
#       1 # import class for visualizing complete supervised learning (i.e., noisy sampled function approximation)
# ----> 2 from Data_Fit_Demo_3d import two_dim_regression_fits
#       3 get_ipython().magic(u'matplotlib inline')
#       4 data_fit = two_dim_regression_fits()
#       5 data_fit.load_data('demo_datasets/3d_noisy_sin_sample.csv')
#
# ImportError: No module named Data_Fit_Demo_3d

# %%
# import gridworld library - make sure this is executed prior to running any gridworld cell
import sys
import numpy as np
sys.path.append('demo_python_backend_files')
# %matplotlib inline

# import class for visualizing complete supervised learning (i.e., noisy sampled function approximation)
from regression_viz_lib import Data_Fit_Demo_3d as demo
data_fit = demo.two_dim_regression_fits()
data_fit.load_data('demo_datasets/3d_noisy_sin_sample.csv')
data_fit.load_target('demo_datasets/3d_sin_function.csv')
data_fit.browse_fit(model = 'tree',param_range = np.arange(1,20))
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgVBHZVZYQKXEJIXPN">
#     <br>
#     <input id="_anim_sliderVBHZVZYQKXEJIXPN" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animVBHZVZYQKXEJIXPN.set_frame(parseInt(this.value));"></input>
#     <br>
#
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgVBHZVZYQKXEJIXPN";
#     var slider_id = "_anim_sliderVBHZVZYQKXEJIXPN";
#     var loop_select_id = "_anim_loop_selectVBHZVZYQKXEJIXPN";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#
#
#     /* set a timeout to make sure all the above elements are created before
#        the object is initialized. */
#     setTimeout(function() {
#         animVBHZVZYQKXEJIXPN = new Animation(frames, img_id, slider_id, 52, loop_select_id);
#     }, 0);
#   })()
# </script>

# %%
# import gridworld library - make sure this is executed prior to running any gridworld cell
import sys
import numpy as np
sys.path.append('demo_python_backend_files')
# %matplotlib inline

# import class for visualizing complete supervised learning (i.e., noisy sampled function approximation)
from regression_viz_lib import Data_Fit_Demo_3d as demo
data_fit = demo.two_dim_regression_fits()
data_fit.load_data('demo_datasets/3d_noisy_sin_sample.csv')
data_fit.load_target('demo_datasets/3d_sin_function.csv')
data_fit.browse_fit(model = 'nnet',param_range = np.arange(1,20))
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgOLDKZJLSULTEODQY">
#     <br>
#     <input id="_anim_sliderOLDKZJLSULTEODQY" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animOLDKZJLSULTEODQY.set_frame(parseInt(this.value));"></input>
#     <br>
#
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgOLDKZJLSULTEODQY";
#     var slider_id = "_anim_sliderOLDKZJLSULTEODQY";
#     var loop_select_id = "_anim_loop_selectOLDKZJLSULTEODQY";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#
#
#     /* set a timeout to make sure all the above elements are created before
#        the object is initialized. */
#     setTimeout(function() {
#         animOLDKZJLSULTEODQY = new Animation(frames, img_id, slider_id, 52, loop_select_id);
#     }, 0);
#   })()
# </script>

# %%
# import gridworld library - make sure this is executed prior to running any gridworld cell
import sys
import numpy as np
sys.path.append('demo_python_backend_files')
# %matplotlib inline

# import class for visualizing complete supervised learning (i.e., noisy sampled function approximation)
from regression_viz_lib import Data_Fit_Demo_3d as demo
data_fit = demo.two_dim_regression_fits()
data_fit.load_data('demo_datasets/3d_noisy_sin_sample.csv')
data_fit.load_target('demo_datasets/3d_sin_function.csv')
data_fit.browse_fit(model = 'nnet',param_range = np.arange(1,20))
