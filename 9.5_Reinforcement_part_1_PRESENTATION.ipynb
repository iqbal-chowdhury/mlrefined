# %% [markdown]
#
#
#   <span style="color: black; font-family: Babas; font-size: 2em;">Reinforcement Learning Series</span>
#
#   <span style="color: black; font-family: Garamond; font-size: 1.3em;">Chi-Town Machine Learning Meetup</span>
#
#
#   <p><img src= "demo_images/RL_images/maze.gif",style=border:0px;margin:0px;float:left;width:400px;>
#   </p>
#   <p> <br></p>
#
# <p>
# <img src= "demo_images/RL_images/looping_pacman.gif",style=border:0px;margin:0px;float:left;width:400px;>
#   </p>
#
#
# <p> <br><br><br><br><br></p>
#
# <p>
#   <img src="demo_images/RL_images/lunar_lander.gif",style=border:0px;margin:30px;float:left;width:400px;>
#     </p>
#
# <p>
#  <img src="demo_images/RL_images/chess.gif",style=border:0px;margin:20px;float:left;width:300px;>
#   </p>

# %% [markdown]
# <p>
# <img src="demo_images/mlrefined_cover.png",style="border:0px;margin:30px;float:left;width:10px !important;">
# </p>
#
#  <p>
#
# This presentation is supplementary material for the textbook Machine Learning Refined (Cambridge University Press, 2016). Visit
#
# <a href="http://www.mlrefined.com">our book website</a>
#
# for free chapter downloads and tutorials, <a href = "https://github.com/jermwatt/mlrefined"> our github page </a> for tons of code demos and notebooks, and <a href = "https://www.amazon.com/Machine-Learning-Refined-Foundations-Applications/dp/1107123526/ref=sr_1_1?ie=UTF8&qid=1474491657&sr=8-1&keywords=machine+learning+refined"> our Amazon site here </a> for details regarding a hard copy of the text.
# </p>

# %% [markdown]
#
#
#   <span style="color: black; font-family: Babas; font-size: 2em;">Reinforcement Learning Series</span>
#
#   <span style="color: black; font-family: Garamond; font-size: 1.3em;">Chi-Town Machine Learning Meetup</span>

# %% [markdown]
#
#
#   <span style="color: black; font-family: Babas; font-size: 2em;">Reinforcement Learning Series</span>
#
#   <span style="color: black; font-family: Garamond; font-size: 1.3em;">Part 1: Fundamentals</span>
#
#
#  <p> <img src= "demo_images/RL_images/maze.gif",style=border:0px;margin:0px;float:center;width:500px;>
#
# </p>

# %% [markdown]
# # What this Series is all about

# %% [markdown]
# ## What this Series is all about

# %% [markdown]
# - Learning RL is tough!

# %% [markdown]
# -  Requires use of advanced ideas from machine learning
#     - e.g., mathematical optimization, deep  networks

# %% [markdown]
# - Series of talks introduces RL by pulling apart entire process

# %% [markdown]
# - We will develop important intuition about the strengths and limitations of Reinforcement paradigm.

# %% [markdown]
# # What this presentation is all about

# %% [markdown]
# ## What this presentation is all about

# %% [markdown]
# - Here we introduce the fundamentals

# %% [markdown]
# - In particular: the Q-Learning algorithm

# %% [markdown]
# - Future talks cover more advanced concepts
#
#     e.g., how to integrate in deep networks

# %% [markdown]
# # What is Reinforcement Learning (RL)?

# %% [markdown]
# - A general framework for building computational agents which can, if trained properly, act intelligently in a well-defined but dynamic environment.

# %% [markdown]
# -  Three main application areas in which RL is commonly used: robotics, automatic control, and game AI.

# %% [markdown]
# # Common applications of Reinforcement?

# %% [markdown]
# ## Example: Robotics (e.g., shortest path) - Gridworld
#
# <p>
# <img src="demo_images/RL_images/maze.gif",width=600,height=600></p>

# %% [markdown]
# ## Example: Robotics (e.g., shortest path) - Gridworld
#
# <p>
# <img src="demo_images/RL_images/moat.gif",width=600,height=600></p>

# %% [markdown]
# ## Example: Robotics (e.g., shortest path - Gridworld
#
# <p>
# <img src="demo_images/RL_images/random.gif",width=600,height=600></p>

# %% [markdown]
# ##  Example:  Game playing agents
#
# <p>
# <img src="demo_images/RL_images/chess.gif",width=500,height=500></p>

# %% [markdown]
# ##  Example:  Game playing agents
#
# <p>
# <img src="demo_images/RL_images/looping_pacman.gif",width=600,height=600></p>

# %% [markdown]
# ### Example:   Control problems  (e.g., inverted pendulum)
#
# <p>
# <img src="demo_images/RL_images/cartpole.gif",width=700></p>

# %% [markdown]
# ### Example:   Control problems (e.g., lunar lander)
# <p>
# <img src="demo_images/RL_images/lunar_lander.gif",width=600,height=600></p>

# %% [markdown]
# # Principles of Reinforcement

# %% [markdown]
# # Principles of Reinforcement

# %% [markdown]
# - **Principle 1:** Reinforcement Learning automates narrowly focused goal-driven tasks.    Narrowly focused $\neq$ simple.  <p> <img src="demo_images/RL_images/maze.gif" alt="Smiley face" width="200" height="200" align="right"> </p>

# %% [markdown]
# - **Principle 2:**  Experimentation in the space of a problem - commonly a realistic simulation of a problem's environment -  is crucial to training a Reinforcement Learning agent.

# %% [markdown]
# - **Principle 3:** A Reinforcement Learning agent learns by repeated trial-and-error interactions with a problem environment or simulator. <p> <img src="demo_images/RL_images/gridworld_training.gif" width="800" align="middle"> </p>

# %% [markdown]
# - **Principle 4:** Numerical rewards are used to communicate the desired goal to the Reinforcement Learning agent.

# %% [markdown]
# # The fundamental components of an RL problem

# %% [markdown]
# # The fundamental components of an RL problem
#
# 1\.    A **state** is a specific configuration of all objects in a problem's environment
#     - Defined by environment

# %% [markdown]
# 2\.  The agent can then take an **action**
#     - Defined by environment

# %% [markdown]
# 3\.  A **reward** is a numerical signal communicating our desired goal to the agent
#     - Defined by we humans

# %% [markdown]
# ## Example: Gridworld

# %% [markdown]
# - A **state**  current location of the player (the blue square).

# %% [markdown]
# - **Actions** the agent can one square adjacently up, down, left or right.

# %% [markdown]
# - **Rewards**
#     - -1 to all actions leading to non-goal/non-hazard
#     - -100 for those leading to hazard
#     - 0 for actions leading to goal

# %% [markdown]
# ## Example: Chess

# %% [markdown]
# - A **state** is any (legal) configuration of the white and black pieces.

# %% [markdown]
# - An **action** is any legal move of current piece on the board.

# %% [markdown]
# - **Rewards**
#     - action leading to checkmate gives 10000
#     - every other action gives -1

# %% [markdown]
# ## Example:  Inverted pendulum

# %% [markdown]
#  - a **state** is a complete set of information about the cart and pole's position

# %% [markdown]
# - An **action** is moving the cart left or right along the horizontal axis by one unit.

# %% [markdown]
# - **Rewards**
#     - angle between the pole and the horizontal axis is above a certain threshold the reward 1
#     - otherwise reward is 0

# %% [markdown]
# # Formalities and jargon of Reinforcement

# %% [markdown]
# # Modeling and jargon of Reinforcement
#
# - **Principle 3:** A Reinforcement Learning agent learns by repeated trial-and-error interactions with a problem environment or simulator. <p> <img src="demo_images/RL_images/gridworld_training.gif" width="600" height="600" align="middle"> </p>

# %% [markdown]
# 1\.  Run through many **simulations**

# %% [markdown]
# 2\.  Each simulation run is called an **episode**

# %% [markdown]
# 3\. Each movement is called a **step**

# %% [markdown]
# <p> <img src="demo_images/RL_images/gridworld_training.gif" width="900" align="middle"> </p>
#
# 4\. Each step consists of 4 events:
#     - begin at a state
#     - take an action
#     - move to a new state based on action taken
#     - receive reward based on action taken

# %% [markdown]
# # Formal modeling: an episode of steps

# %% [markdown]
# # Formal modeling: an episode of steps

# %% [markdown]
# **step 1:**<br>
# - start at an initial state (denoted by $s_0$)<br>
# - take an action (denoted by $a_1$)<br>
# - arrive at state (denoted by $s_1$), receive first reward $r_1$<br>

# %% [markdown]
# **step 2:**<br>
# - start at state $s_1$<br>
# - take an action (denoted by $a_2$)<br>
# - arrive at new state (denoted by $s_2$) and receive second reward $r_2$<br>

# %% [markdown]
# **step 3:**<br>
# - start at state $s_2$<br>
# - take an action (denoted by $a_3$)<br>
# - arrive at new state (denoted by $s_3$) and and receive third reward $r_3$<br>

# %% [markdown]
# **step 4:**<br>
# ...<br>

# %% [markdown]
# Written more compactly as:
#
# ($s_0$, $a_1$, $r_1$), ($s_1$, $a_2$, $r_2$), ($s_2$, $a_3$, $r_3$), ($s_3$,...

# %% [markdown]
# # Step back: what are we after again?

# %% [markdown]
# - simulations $\longrightarrow$ episodes $\longrightarrow$ steps
#
# ($s_0$, $a_1$, $r_1$), ($s_1$, $a_2$, $r_2$), ($s_2$, $a_3$, $r_3$), ($s_3$,...

# %% [markdown]
# - want: **optimal actions leading to greatest long-term reward**

# %% [markdown]
# # Reinforcement fundamentals: the Q cost function

# %% [markdown]
# # The Q cost function

# %% [markdown]
# - want: **optimal actions leading to greatest long-term reward**

# %% [markdown]
# - expressing this desire in math gives us so-called Q cost

# %% [markdown]
# - derivation uses common math trick

# %% [markdown]
# - assume what you want, use it to derive (**recursive equations**)

# %% [markdown]
# ## The Q cost function: derivation
#
# - take a sequence of steps:
#
# ($s_0$, $a_1$, $r_1$), ($s_1$, $a_2$, $r_2$), ($s_2$, $a_3$, $r_3$), ($s_3$,...

# %% [markdown]
# - start at $s_0$
# $\longrightarrow$ take any first action $a_1$ $\longrightarrow$  recieve reward $r_1$

# %% [markdown]
# -  **now assume every further action is optimal**

# %% [markdown]
# - denote the resulting maximal long-term reward: $Q(s_0,a_1)$

# %% [markdown]
# ## The Q cost function: derivation
#
# - denote the resulting maximal long-term reward by $Q(s_0,a_1)$

# %% [markdown]
# - only action **not** potentially optimal is first at $s_0$ i.e., $a_1$

# %% [markdown]
# - then maximum total reward from $s_0$ :   $\underset{i}{\text{maximum}}\,\,Q\left(s_{0},\,\alpha_{i}\right)$

# %% [markdown]
# ## The Q cost function: derivation
#
# - then maximum total reward from $s_0$ is:   $\underset{i}{\text{maximum}}\,\,Q\left(s_{0},\,\alpha_{i}\right)$

# %% [markdown]
# - with this $Q$ is defined *recursively* in terms of itself

# %% [markdown]
# - $Q(s_0,a_1)$ must be the sum of $r_1$ **and** the *maximum possible sum of rewards for all subsequent steps:* $\underset{i}{\text{maximum}}\,\,Q\left(s_{1},\,\alpha_{i}\right)$.

# %% [markdown]
# - Algebraically:   $Q\left(s_{0},\,a_{1}\right)=r_{1}+\underset{i=1}{\text{maximum}}\,\,Q\left(s_{1},\,\alpha_{i}\right)$

# %% [markdown]
# ## The Q cost function: derivation
#
# So can approximate $Q$ by running through an episode of simulation
#
# ($s_0$, $a_1$, $r_1$), ($s_1$, $a_2$, $r_2$), ($s_2$, $a_3$, $r_3$), ($s_3$,...

# %% [markdown]
# and updating $Q$ recursively at each step:

# %% [markdown]
# $Q\left(s_{0},\,a_{1}\right)=r_{1}+\underset{i=1...M}{\text{maximum}}\,\,Q\left(s_{1},\,\alpha_{i}\right)$

# %% [markdown]
# $Q\left(s_{1},\,a_{2}\right)=r_{2}+\underset{i=1...M}{\text{maximum}}\,\,Q\left(s_{2},\,\alpha_{i}\right)$

# %% [markdown]
# $Q\left(s_{2},\,a_{3}\right)=r_{3}+\underset{i=1...M}{\text{maximum}}\,\,Q\left(s_{3},\,\alpha_{i}\right)$
#
# $\vdots$

# %% [markdown]
# $Q\left(s_{k-1},\,a_{k}\right)=r_{k}+\underset{i=1...M}{\text{maximum}}\,\,Q\left(s_{k},\,\alpha_{i}\right)$
#
# $\vdots$

# %% [markdown]
# ## The Q cost function: derivation
#
# - This is called **the Q-Learning Algorithm**

# %% [markdown]
# - works by approximating $Q$ iteratively

# %% [markdown]
# - updating $Q$ recursively at each step of each simulation

# %% [markdown]
# - exactly as shown here
# <p>
# <img src="demo_images/RL_images/gridworld_training.gif" width="800" align="middle"> </p>

# %% [markdown]
# ### Q -learning pseudo-code
# Initialize $Q$
#
# **for** e = 1...E (the maximum number of episodes)
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Select a random initial state $s_0$ and set $k=1$
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; **while** end state not reached AND maximum iteration count not met
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;select the action $a_k$ at random and record the resulting state $s_k$ and corresponding reward $r_k$
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;update $Q$ as
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$Q\left(s_{k-1},\,a_{k}\right)=r_{k}+\underset{i=1...M}{\text{maximum}}\,\,Q\left(s_{k},\,\alpha_{i}\right)$
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$k \longleftarrow k+1$

# %% [markdown]
# # Q-learning for the gridworld maze

# %%
### start main Q-learning loop ###
for n in range(self.training_episodes): 
    # pick this episode's starting position
    grid.agent = self.training_start_schedule[n]

    # update Q matrix while loc != goal
    episode_history = []      # container for storing this episode's journey
    total_episode_reward = 0
    for step in range(self.max_steps):   
        # update episode history container
        episode_history.append(grid.agent)

        ### if you reach the goal end current episode immediately
        if grid.agent == grid.goal:
            break

        # translate current agent location tuple into index
        s_k_1 = grid.state_tuple_to_index(grid.agent)

        # get action
        a_k = grid.get_action(method = self.action_method,Q = Q,exploit_param = self.exploit_param)

        # move based on this action
        s_k = grid.get_movin(action = a_k)

        # get reward     
        r_k = grid.get_reward(state_index = s_k)          

        # update Q
        Q[s_k_1,a_k] = r_k + max(Q[s_k,:])

        # update current location of agent 
        grid.agent = grid.state_index_to_tuple(state_index = s_k)

# %% [markdown]
# ## Applying Q-learning to the gridworld maze

# %%
# import gridworld library - make sure this is executed prior to running any gridworld cell
import sys
sys.path.append('demo_python_backend_files')
# %matplotlib inline

# %%
# import custom gridworld simulator 
from gridworld_lib import gridworld_enviro

# generate instance of gridworld
small_maze = gridworld_enviro.environment(world_size = 'small', world_type = 'maze')

# show the grid
small_maze.color_gridworld()

# %% [markdown]
# ## Applying Q-learning to the gridworld maze

# %%
# import q-learning module
from gridworld_lib import gridworld_qlearn

# create an instance of the q-learner
qlearner = gridworld_qlearn.learner(gridworld = small_maze,action_method = 'random')

# run q-learning
qlearner.train(verbose = True)
# Out:
# training episode 50 of 500 complete
# training episode 100 of 500 complete
# training episode 150 of 500 complete
# training episode 200 of 500 complete
# training episode 250 of 500 complete
# training episode 300 of 500 complete
# training episode 350 of 500 complete
# training episode 400 of 500 complete
# training episode 450 of 500 complete
# training episode 500 of 500 complete
# q-learning algorithm complete

# %%
# load in gridworld animation module
from gridworld_lib import gridworld_animators

# create instance of animator
animator = gridworld_animators.animator()

### animate training runs of one algorithm ###
animator.animate_training_runs(gridworld = small_maze, learner = qlearner,episodes = [1,25,30,100])
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
# ...

# %% [markdown]
# ## Does Q-Learning work?

# %% [markdown]
# ## Does Q-Learning work?

# %%
# load in gridworld animation module
from gridworld_lib import gridworld_animators

# create instance of animator
animator = gridworld_animators.animator()

# animate a fully trained agent 
locs = [[9,0],[0,0],[5,5]]
animator.animate_validation_runs(gridworld = small_maze,learner = qlearner,starting_locations = locs)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
# ...

# %% [markdown]
# # How about on other gridworlds?

# %% [markdown]
# # how about a random world?

# %%
# import custom gridworld simulator 
from gridworld_lib import gridworld_enviro

# generate instance of gridworld
small_maze = gridworld_enviro.environment(world_size = 'small', world_type = 'random')

# show the grid
small_maze.color_gridworld()

# %%
# import q-learning module
from gridworld_lib import gridworld_qlearn

# create an instance of the q-learner
qlearner = gridworld_qlearn.learner(gridworld = small_maze,action_method = 'random')

# run q-learning
qlearner.train(verbose = True)
# Out:
# training episode 50 of 500 complete
# training episode 100 of 500 complete
# training episode 150 of 500 complete
# training episode 200 of 500 complete
# training episode 250 of 500 complete
# training episode 300 of 500 complete
# training episode 350 of 500 complete
# training episode 400 of 500 complete
# training episode 450 of 500 complete
# training episode 500 of 500 complete
# q-learning algorithm complete

# %%
# load in gridworld animation module
from gridworld_lib import gridworld_animators

# create instance of animator
animator = gridworld_animators.animator()

# animate a fully trained agent 
locs = [[9,0],[0,0],[5,5]]
animator.animate_validation_runs(gridworld = small_maze,learner = qlearner,starting_locations = locs)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
# ...

# %% [markdown]
# # How about the moat (of doom?!!!)

# %%
# import custom gridworld simulator 
from gridworld_lib import gridworld_enviro

# generate instance of gridworld
small_maze = gridworld_enviro.environment(world_size = 'small', world_type = 'moat')

# show the grid
small_maze.color_gridworld()

# %%
# import q-learning module
from gridworld_lib import gridworld_qlearn

# create an instance of the q-learner
qlearner = gridworld_qlearn.learner(gridworld = small_maze,action_method = 'random')

# run q-learning
qlearner.train(verbose = True)
# Out:
# training episode 50 of 500 complete
# training episode 100 of 500 complete
# training episode 150 of 500 complete
# training episode 200 of 500 complete
# training episode 250 of 500 complete
# training episode 300 of 500 complete
# training episode 350 of 500 complete
# training episode 400 of 500 complete
# training episode 450 of 500 complete
# training episode 500 of 500 complete
# q-learning algorithm complete

# %%
# load in gridworld animation module
from gridworld_lib import gridworld_animators

# create instance of animator
animator = gridworld_animators.animator()

# animate a fully trained agent 
locs = [[9,0],[0,0],[5,5]]
animator.animate_validation_runs(gridworld = small_maze,learner = qlearner,starting_locations = locs)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
# ...

# %% [markdown]
# # Summary
#
# - discussed basic principles involved in Reinforcement Learning
#
# - the components (state, action, rewards)
#
# - common notation and jargon
#
# - derivation of fundamental $Q$ function Q-Learning algorithm

# %% [markdown]
# ## Coming up next in the Reinforcement Learning Series...

# %% [markdown]
# - common enhancements for the basic Q-Learning scheme discussed here

# %% [markdown]
# - features, mathematical optimization + RL

# %% [markdown]
# - why and how common function approximators such as deep neural etworks are integrated into the Reinforcement framework

# %% [markdown]
# - many more implementations of RL applied to control and game AI problems

# %% [markdown]
# <a id='bib_cell'></a>
#
# ## Notes and bibliography
#
# [0] Harmon, Mance E., and Stephanie S. Harmon. Reinforcement Learning: A Tutorial. No. WL-TR-97-1028. WRIGHT LAB WRIGHT-PATTERSON AFB OH, 1997
#
# [1]  There are many algorithms specifically designed to solve just this task - the most popular being [Dijkstra’s and A\* algorithms](http://www.redblobgames.com/pathfinding/a-star/introduction.html).  However the more flexible RL framework too provides great results.
#
# [2] Lai, Matthew. "Giraffe: Using deep reinforcement learning to play chess." arXiv preprint arXiv:1509.01549 (2015).
# APA
#
# [3]  Mnih, Volodymyr, et al. "Playing atari with deep reinforcement learning." arXiv preprint arXiv:1312.5602 (2013).
#
# [4]  Image taken from http://ai.berkeley.edu/project_overview.html
#
# [5] Watkins, Christopher JCH, and Peter Dayan. "Q-learning." Machine learning 8.3-4 (1992): 279-292.
#
# [6]  Image taken from https://gym.openai.com/
