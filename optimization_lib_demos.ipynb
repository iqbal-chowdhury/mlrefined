# %%
import sys
sys.path.append('demo_python_backend_files')
import optimization_viz_lib
# %matplotlib inline

# %%
from optimization_viz_lib import ConvexGradViz
demo = ConvexGradViz.visualizer()
demo.run_demo()

# %%
from optimization_viz_lib import NonconvexGradViz
demo = NonconvexGradViz.visualizer()
demo.run_demo()

# %%
from IPython.display import HTML
from IPython.display import display, HTML

def video(fname, mimetype):
    video_encoded = open(fname, "rb").read().encode("base64")
    video_tag = '<video controls alt="test" src="data:video/{0};base64,{1}">'.format(mimetype, video_encoded)
    return HTML(data=video_tag)

# %%
video('convex_gradrun.mp4',"mp4")
# Out:
# <video controls alt="test" src="...
