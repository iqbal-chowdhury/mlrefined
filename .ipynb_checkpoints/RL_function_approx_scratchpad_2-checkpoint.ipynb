# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import autograd.numpy as np  # Thinly-wrapped numpy
from autograd import grad as compute_grad   # The only autograd function you may ever need
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
# plot gridworld with arros
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.patches as patches
import copy

# import gridworld library - make sure this is executed prior to running any gridworld cell
import sys
sys.path.append('demo_python_backend_files')
# %matplotlib notebook

# %%
### setup arrows
def add_arrows(ax,state,action):
    x = state[1]
    y = state[0]
    dx = 0
    dy = 0

    ### switch for starting point of arrow depending on action - so that arrow always centered ###
    if action == 0:    # action == down
        y += 0.9
        x += 0.5
        dy = -0.8
    if action == 1:    # action == up
        x += 0.5
        y += 0.1
        dy = 0.8
    if action == 2:    # action == left
        y += 0.5
        x += 0.9
        dx = -0.8
    if action == 3:    # action == right
        y += 0.5
        x += 0.1
        dx = 0.8

    ### add patch with location / orientation determined by action ###
    ax.add_patch(
       patches.FancyArrowPatch(
       (x, y),
       (x+dx, y+dy),
       arrowstyle='->',
       mutation_scale=30,
       lw=2
       )
    )

# best action map
def draw_arrow_map(ax,world,states,best_actions):  
    ### setup colormap
    colors = [(0.9,0.9,0.9),(255/float(255), 119/float(255), 119/float(255)), (66/float(255),244/float(255),131/float(255)), (1/float(255),100/float(255),200/float(255)),(0,0,0)]  
    my_cmap = LinearSegmentedColormap.from_list('colormapX', colors, N=100)

    ### setup grid
    p_grid = world.grid
    p_grid[world.goal[0]][world.goal[1]] = 2   
    ax.pcolormesh(p_grid,edgecolors = 'k',linewidth = 0.01,vmin=0,vmax=4,cmap = my_cmap)

    # clean up plot
    ax.set_xlim(-0.1,world.width );
    ax.set_ylim(-0.1,world.height); 
    
    ### go over states and draw arrows indicating best action
    # for i in range(len(states)):
    for i in range(len(best_actions)):
        state = states[i]
        if state[0] != world.goal[0] or state[1] != world.goal[1]:  
            action = best_actions[i]
            add_arrows(ax,state,action)

# %% [markdown]
# # Run function approx Q learner and visualize Q functions

# %%
# %matplotlib inline

# import custom gridworld simulator 
from gridworld_lib import gridworld_enviro_func_approx

# generate instance of gridworld
world = gridworld_enviro_func_approx.environment(world_size = 'tiny', world_type = 'demo',training_episodes = 1000)

# %%
from gridworld_lib import gridworld_qlearn_func_approx

# create an instance of the q-learner
approximator = 'cosine'
degree = 10
qlearner_func = gridworld_qlearn_func_approx.learner(exploit_param = 0.5,gridworld = world,gamma = 0.9,approximator = approximator,degree = degree,training_episodes = 500)

# run q-learning
qlearner_func.train(verbose = True, action_method = 'random')
# Out:
# training episode 50 of 500 complete
# training episode 100 of 500 complete
# training episode 150 of 500 complete
# training episode 200 of 500 complete
# training episode 250 of 500 complete
# training episode 300 of 500 complete
# training episode 350 of 500 complete
# training episode 400 of 500 complete
# training episode 450 of 500 complete
# training episode 500 of 500 complete
# q-learning algorithm complete

# %%
# %matplotlib notebook
W = qlearner_func.W

# generate input values
s = np.linspace(0,world.height,500)
t = np.linspace(0,world.width,500)
s_1,s_2 = np.meshgrid(s,t)

# build 4 polynomial basis elements
fig = plt.figure(num=None, figsize = (9,3), dpi=80, facecolor='w', edgecolor='k')
colors = ['r','g','b','k']

### create Q action functions ###
F = np.zeros((4,np.shape(s_1)[0],np.shape(s_1)[1]))
for m in range(4):    
    # construct approximator from learned weights
    f_m = np.zeros((np.shape(s_1)))
    w = W[m]
    
    # choose between approximators
    if approximator == 'linear':
        w0 = w[0][0]
        w1 = w[0][1]
        w2 = w[0][2]
        f_m += w0 +  w1*s_1 + w2*s_2
        
    elif approximator == 'cosine':
        for n in range(np.shape(W)[1]):
            w0 = w[n][0]
            w1 = w[n][1]        
            tweak = n/float(max(world.height,world.width))
            f_m += w0 + w1*(np.cos(tweak*s_1))*(np.cos(tweak*s_2))
   
    F[m,:,:] = f_m
    
### plot each Q function ###
for m in range(4):
    f_m = F[m,:,:]       
    ax1 = plt.subplot(1,4,m+1,projection = '3d')
    ax1.plot_surface(s_1,s_2,f_m,alpha = 0.1,color = colors[m],zorder = 0,shade = True,linewidth=0.5,antialiased = True,cstride = 20, rstride = 15)
    ax1.view_init(10,20)  

fig.subplots_adjust(left=0,right=1,bottom=0,top=1)   # remove whitespace around 3d figure
# Out:
# <img src="data:image/png;base64,...">

# %%
### generate states and final actions ###
# process states for scatter plotting
states = world.states 

# process states for scatter plotting
plot_ready_states = np.zeros((len(states),2))
for i in range(len(states)):
    a = states[i]
    b = a.split(',')
    state = [int(b[0])]
    state.append(int(b[1]))
    plot_ready_states[i,0] = state[0]
    plot_ready_states[i,1] = state[1]

plot_ready_states = np.zeros((len(states),2))
for i in range(len(states)):
    a = states[i]
    b = a.split(',')
    state = [int(b[0])]
    state.append(int(b[1]))
    plot_ready_states[i,0] = state[0]
    plot_ready_states[i,1] = state[1]
    
### compute actions ###
q_dir = []
for i in range(len(plot_ready_states)):
    state = plot_ready_states[i]
    state1 = state[0]
    state2 = state[1]
    
    g = []
    for m in range(4):
        w = W[m]
        f_m = 0
        
        # choose between approximators
        if approximator == 'linear':
            w0 = w[0][0]
            w1 = w[0][1]
            w2 = w[0][2]
            f_m += w0 +  w1*state1 + w2*state2

        elif approximator == 'cosine':
            for n in range(np.shape(W)[1]):
                w0 = w[n][0]
                w1 = w[n][1]        
                tweak = n/float(max(world.height,world.width))
                f_m += w0 + w1*(np.cos(tweak*state1))*(np.cos(tweak*state2)) - 1
                
        # store computation
        g.append(f_m)
        
    # go 
    ind = np.argmax(g)
    q_dir.append(ind)

# %%
### setup figure ###
fig = plt.figure(num=None, figsize = (10,5), dpi=80, facecolor='w', edgecolor='k')

# plot regression surface 
ax1 = plt.subplot(1,2,1,projection = '3d')
colors = ['r','g','b','k']

#### find optimal policy surface ####
F2 = copy.deepcopy(F)

# reshape and find max
f1 = F2[0,:,:]
f2 = F2[1,:,:]
f3 = F2[2,:,:]
f4 = F2[3,:,:]

f1.shape = (np.prod(np.shape(f1)),1)
f2.shape = (np.prod(np.shape(f2)),1)
f3.shape = (np.prod(np.shape(f3)),1)
f4.shape = (np.prod(np.shape(f4)),1)

c = np.hstack((f1,f2,f3,f4))
ind = np.argmax(c,axis = 1)

### construct optimal policy function ###
for m in range(4):
    f_m = F2[m,:,:]
    f_m.shape = (np.prod(np.shape(f_m)),1)
    ind2 = np.argwhere(ind != m)
    ind2 = [v[0] for v in ind2]
    
    # plot any portion of the function that is maximal
    if len(ind2) < np.size(f_m):
        f_m[ind2] = np.nan
        f_m.shape = (np.shape(F2[m,:,:]))

        # plot two surfaces - top and bottom steps
        ax1.plot_surface(s_1,s_2,f_m,alpha = 0.1,color = colors[m],zorder = 0,shade = True,linewidth=0.5,antialiased = True,cstride = 20, rstride = 15)

ax1.view_init(40,0)  
        
# ax1.legend['down','up','left','right'],loc='center right', bbox_to_anchor=(1, 0.5))
    
### plot arrows ###
ax2 = plt.subplot(1,2,2)
draw_arrow_map(ax2, world,plot_ready_states,q_dir)
# Out:
# <img src="data:image/png;base64,...">

# %%
q_dir
# Out:
# []

# %%
a = [0,2]
a.insert(0,1)
print (a)
# Out:
# [1, 0, 2]

# %%
# # import gridworld library - make sure this is executed prior to running any gridworld cell
# import sys
# sys.path.append('demo_python_backend_files')
# %matplotlib inline

# # import custom gridworld simulator 
# from gridworld_lib import gridworld_enviro

# # generate instance of gridworld
# small_maze = gridworld_enviro.environment(world_size = 'small', world_type = 'maze')

# # show the grid
# # small_maze.color_gridworld()

# # import q-learning module
# from gridworld_lib import gridworld_qlearn

# # create an instance of the q-learner
# qlearner = gridworld_qlearn.learner(gridworld = small_maze)

# # run q-learning
# qlearner.train(verbose = False, action_method = 'exploit')

# # pull states and Q matrix for plotting
# states = small_maze.states 
# Q = qlearner.Q

# # process states for scatter plotting
# plot_ready_states = np.zeros((len(states),2))
# for i in range(len(states)):
#     a = states[i]
#     b = a.split(',')
#     state = [int(b[0])]
#     state.append(int(b[1]))
#     plot_ready_states[i,0] = state[0]
#     plot_ready_states[i,1] = state[1]
    
# %matplotlib notebook
# # build figure for Q functions
# fig = plt.figure(num=None, figsize = (10,3), dpi=80, facecolor='w', edgecolor='k')

# ### create figure ###
# for m in range(4):
#     # make panel for plotting in 3d
#     ax1 = plt.subplot(1,4,m+1,projection = '3d')

#     # scatter plot
#     ax1.scatter(plot_ready_states[:,0],plot_ready_states[:,1],Q[:,m])
    
#     # clean up plot
#     ax1.view_init(10,20)  
#     ax1.set_title('$q_'+str(m+1) + '$',fontsize = 18)

# fig.subplots_adjust(left=0,right=1,bottom=0,top=1)   # remove whitespace around 3d figure
# plt.show()

# %matplotlib notebook
# # compute optimal policy
# q_max = np.zeros((len(Q[:,0]),1))
# q_dir = np.zeros((len(Q[:,0]),1))
# for i in range(len(Q[:,0])):
#     max_ind = np.argmax(Q[i,:])
#     q_dir[i] = max_ind
#     max_val = Q[i,max_ind]
#     q_max[i] = max_val

# q_dir = q_dir.tolist()
# q_dir = [int(s[0]) for s in q_dir]
# labels = ['down','up','left','right']
# colors = ['r','g','b','k']

# # build figure for Q functions
# fig = plt.figure(num=None, figsize = (10,3), dpi=80, facecolor='w', edgecolor='k')
# # make panel for plotting in 3d
# ax1 = plt.subplot(1,2,1,projection = '3d')
# # scatter plot
# for i in range(len(plot_ready_states)):
#     ax1.scatter(plot_ready_states[i,0],plot_ready_states[i,1],q_max[i],c =colors[q_dir[i]])
    
# # clean up plot
# ax1.view_init(40,0)  
# ax1.set_title('$q_{max}$',fontsize = 18)
# ax1.legend(labels,loc='center right', bbox_to_anchor=(1, 0.5))
# leg = ax1.get_legend()

# for i in range(4):
#     leg.legendHandles[i].set_color(colors[i])

# fig.subplots_adjust(left=0,right=1,bottom=0,top=1)   # remove whitespace around 3d figure

# ax2 = plt.subplot(1,2,2)
# draw_arrow_map(ax2, small_maze,plot_ready_states,q_dir)
# plt.show()
